# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

from sklearn.linear_model import Lasso, Ridge, ElasticNet

# %%
df = pd.read_csv("C:/Users/gpro0/OneDrive/Рабочий стол/Data Science course/mobile phone price prediction.csv")
df.head()
# Out:
#    Unnamed: 0                                  Name  Rating  Spec_score  \
# 0           0                 Samsung Galaxy F14 5G    4.65          68
# 1           1                    Samsung Galaxy A11    4.20          63
# 2           2                    Samsung Galaxy A13    4.30          75
# 3           3                    Samsung Galaxy F23    4.10          73
# 4           4  Samsung Galaxy A03s (4GB RAM + 64GB)    4.10          69
#
#                        No_of_sim       Ram            Battery     Display  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE,   4 GB RAM  6000 mAh Battery   6.6 inches
# 1      Dual Sim, 3G, 4G, VoLTE,   2 GB RAM  4000 mAh Battery   6.4 inches
# 2      Dual Sim, 3G, 4G, VoLTE,   4 GB RAM  5000 mAh Battery   6.6 inches
# 3      Dual Sim, 3G, 4G, VoLTE,   4 GB RAM   6000 mAh Battery  6.4 inches
# 4      Dual Sim, 3G, 4G, VoLTE,   4 GB RAM  5000 mAh Battery   6.5 inches
#
#                                               Camera  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1370 entries, 0 to 1369
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         1370 non-null   int64
#  1   Name               1370 non-null   object
#  2   Rating             1370 non-null   float64
#  3   Spec_score         1370 non-null   int64
#  4   No_of_sim          1370 non-null   object
#  5   Ram                1370 non-null   object
#  6   Battery            1370 non-null   object
#  7   Display            1370 non-null   object
#  8   Camera             1370 non-null   object
#  9   External_Memory    1370 non-null   object
#  10  Android_version    927 non-null    object
#  11  Price              1370 non-null   object
#  12  company            1370 non-null   object
#  13  Inbuilt_memory     1351 non-null   object
#  14  fast_charging      1281 non-null   object
#  15  Screen_resolution  1368 non-null   object
# ...

# %%
for i in df.select_dtypes(include=['float']).columns:
    df[i]=df[i].fillna(df[i].mean())
df.isna().sum()
# Out:
# Unnamed: 0             0
# Name                   0
# Rating                 0
# Spec_score             0
# No_of_sim              0
# Ram                    0
# Battery                0
# Display                0
# Camera                 0
# External_Memory        0
# Android_version      443
# Price                  0
# company                0
# Inbuilt_memory        19
# fast_charging         89
# Screen_resolution      2
# Processor             28
# Processor_name         0
# dtype: int64

# %%
for i in df.select_dtypes(['object']).columns:
    df[i] = df[i].fillna(df[i].mode()[0])
df.isna().sum()
# Out:
# Unnamed: 0           0
# Name                 0
# Rating               0
# Spec_score           0
# No_of_sim            0
# Ram                  0
# Battery              0
# Display              0
# Camera               0
# External_Memory      0
# Android_version      0
# Price                0
# company              0
# Inbuilt_memory       0
# fast_charging        0
# Screen_resolution    0
# Processor            0
# Processor_name       0
# dtype: int64

# %%
col = df.select_dtypes(['object']).columns
le=LabelEncoder()
for i in col:
    df[i]=le.fit_transform(df[i])
df.head()
# Out:
#    Unnamed: 0  Name  Rating  Spec_score  No_of_sim  Ram  Battery  Display  \
# 0           0   860    4.65          68          1   10       86       43
# 1           1   805    4.20          63          3    6       20       28
# 2           2   807    4.30          75          3   10       62       43
# 3           3   867    4.10          73          3   10       85       28
# 4           4   794    4.10          69          3   10       62       34
#
#    Camera  External_Memory  Android_version  Price  company  Inbuilt_memory  \
# 0     187               78                4    442       19               1
# 1      59               83                0    440       19               5
# 2     275               78                3     79       19               7
# 3     139               78                3     79       19               7
# 4      52               78                2     79       19               7
#
#    fast_charging  Screen_resolution  Processor  Processor_name
# ...

# %%
df.drop(["Unnamed: 0", "Name", "Processor_name", "Android_version", "External_Memory", "Camera"], axis=1, inplace=True)

# %%
x=df.drop('Price',axis=1)
y=df.Price
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2)

# %%
from lazypredict.Supervised import LazyRegressor
reg = LazyRegressor(verbose=0, ignore_warnings=False, custom_metric=None)
models, predictions = reg.fit(xtrain,xtest, ytrain, ytest)
# Out:
# 100%|██████████| 42/42 [00:04<00:00, 10.16it/s]
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000142 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 326
# [LightGBM] [Info] Number of data points in the train set: 1096, number of used features: 11
# [LightGBM] [Info] Start training from score 234.824818

# %%
models
# Out:
#                                Adjusted R-Squared  R-Squared   RMSE  \
# Model
# RandomForestRegressor                        0.45       0.47  88.90
# BaggingRegressor                             0.40       0.42  93.08
# ExtraTreesRegressor                          0.38       0.40  94.31
# GradientBoostingRegressor                    0.36       0.38  95.94
# HistGradientBoostingRegressor                0.35       0.38  96.31
# LGBMRegressor                                0.33       0.36  97.79
# XGBRegressor                                 0.33       0.35  98.30
# KNeighborsRegressor                          0.21       0.24 106.69
# AdaBoostRegressor                            0.17       0.20 109.36
# SVR                                          0.08       0.11 115.05
# TransformedTargetRegressor                   0.07       0.11 115.51
# LinearRegression                             0.07       0.11 115.51
# Lars                                         0.07       0.11 115.51
# ...
